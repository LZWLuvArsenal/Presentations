# %% [markdown]
# # 1. Web Scraping/Load Data

# %% [markdown]
# https://medium.com/@lzpdatascience/web-scraping-and-text-summarization-of-news-articles-using-python-2ecfb3e71050

# %%
#Import libraries

from bs4 import BeautifulSoup
import requests
import pandas as pd

# %% [markdown]
# find articles spread over 2 weeks i.e 23 Aug - 5 Sep 2020

# %% [markdown]
# ### 1.1.1 SG Articles

# %% [markdown]
# Article 1: 24 Aug 2020 - https://www.channelnewsasia.com/news/business/pubs-karaoke-nightclubs-covid-19-closing-down-13041928
#
# #### Lights out, music stops: Still-shuttered pubs, karaoke joints call for help amid COVID-19 pandemic

# %%
input_file1 = 'C:/Users/zheng/Desktop/Data Science/Presentations/Mod 9.2/SG Articles/SG Articles 1.txt'

with open(input_file1, 'r') as f:
    SGA1 = f.read()

# %%
print(SGA1[:500])
# Out:
# SINGAPORE: It was early January when PUBking opened its doors to welcome its first customers. But the sight of merry partygoers clinking their glasses and singing their hearts out lasted for just two months before entertainment venues were forced to shut as part of COVID-19 control measures. Nearly five months on, the karaoke pub in Outram remains shut as it is excluded from the list of businesses allowed to reopen. Far from recouping their initial investment of more than S$100,000, its owners h

# %% [markdown]
# Article 2: 27 Aug 2020 - https://www.channelnewsasia.com/news/singapore/covid-19-essential-economic-resources-teo-chee-hean-nscs-13059144
#
# #### COVID-19 has emphasised need to secure flow of essential economic resources: Teo Chee Hean

# %%
input_file2 = 'C:/Users/zheng/Desktop/Data Science/Presentations/Mod 9.2/SG Articles/SG Articles 2.txt'

with open(input_file2, 'r') as f:
    SGA2 = f.read()

print(SGA2[:500])
# Out:
# SINGAPORE: To ensure Singapore's strategic interests are not compromised, the National Security Coordination Secretariat (NSCS) will work with other agencies to strengthen the resilience of the flow of essential economic resources. In the NSCS's addendum to the President's Address, Senior Minister Teo Chee Hean noted the work of the secretariat - a unit under the Prime Minister's Office - in identifying emerging, growing or changing security risks as well as coordinate and ensuring the alignment

# %% [markdown]
# Article 3: 31 Aug 2020 - https://www.channelnewsasia.com/news/singapore/the-big-read-traineeships-amid-gloomy-job-market-13065768
#
# #### The Big Read: Overcoming their scepticism, jobseekers find ray of hope in traineeships amid gloomy job market

# %%
input_file3 = 'C:/Users/zheng/Desktop/Data Science/Presentations/Mod 9.2/SG Articles/SG Articles 3.txt'

with open(input_file3, 'r') as f:
    SGA3 = f.read()

print(SGA3[:500])
# Out:
# SINGAPORE: Polytechnic graduate Andrew Lee was initially sceptical when he was offered a government-backed traineeship with a logistics firm in June. With the Government co-funding 80 per cent of his training allowance, and the company footing the remainder of the bill, he was afraid that the firm might have hired him out of convenience. “Even if you’re not very well-versed in what you’re doing, (the company) wouldn’t mind because they don’t pay much, so that’s my concern,” the 24-year-old said.

# %% [markdown]
# Article 4: 2 Sep - https://www.channelnewsasia.com/news/cnainsider/singapore-race-covid-vaccine-lunar-cov19-human-trial-second-wave-13074106
#
# #### Singapore’s race for a vaccine: Can it be won before second wave of COVID-19 hits?

# %%
input_file4 = 'C:/Users/zheng/Desktop/Data Science/Presentations/Mod 9.2/SG Articles/SG Articles 4.txt'

with open(input_file4, 'r') as f:
    SGA4 = f.read()

print(SGA4[:500])
# Out:
# SINGAPORE: Even though community transmission of COVID-19 has been low in recent weeks, Singapore will have to be prepared for a second wave of infection. The good news is that a vaccine is in development in Singapore. Human clinical trials started last month as volunteers got dosed. But can this race to develop a vaccine be won ahead of the second wave? According to Ooi Eng Eong, deputy director of the Duke-NUS Medical School's emerging infectious diseases programme, there is a “major advantage

# %% [markdown]
# Article 5: 5 Sep - https://www.channelnewsasia.com/news/commentary/food-beverage-restaurant-plastic-use-waste-covid-sustainable-byo-13081568
#
# #### Commentary: COVID-19 a chance for F&B to finally go green

# %%
input_file5 = 'C:/Users/zheng/Desktop/Data Science/Presentations/Mod 9.2/SG Articles/SG Articles 5.txt'

with open(input_file5, 'r') as f:
    SGA5 = f.read()

print(SGA5[:500])
# Out:
# SINGAPORE: The circuit breaker, implemented from April to June in Singapore, was designed to disrupt the spread of COVID-19. It also severely disrupted the food and beverage (F&B) sector, forcing restaurants that were still in operation to focus on home delivery. In the first eight weeks of this period, 1,334 tonnes of disposable cutlery and packaging – the weight of 92 double-decker buses – was produced by the sector, according to a Jun 5 study by National University of Singapore alumni. This w

# %% [markdown]
# ### 1.1.2 UK Articles

# %% [markdown]
# Article 1: 24 Aug 2020: https://www.bbc.com/news/uk-53884401
#
# #### Coronavirus: Teens' anxiety levels dropped during pandemic, study finds

# %%
input_file6 = 'C:/Users/zheng/Desktop/Data Science/Presentations/Mod 9.2/UK Articles/UK Articles 1.txt'

with open(input_file6, 'r') as f:
    UKA1 = f.read()
    
print(UKA1[:500])
# Out:
# Anxiety levels among young teenagers dropped during the coronavirus pandemic, a study has suggested. Thirteen to 14-year-olds were less anxious during lockdown than they had been last October, according to the University of Bristol survey. Researchers surveyed 1,000 secondary school children in south west England. They said the results were a "big surprise" and it raised questions about the impact of the school environment on teenagers' mental health. The findings come after Prof Chris Whitty, t

# %% [markdown]
# Article 2: 27 Aug 2020: https://www.bbc.com/news/health-53938272
#
# #### Coronavirus: Daily cases highest since mid-June

# %%
input_file7 = 'C:/Users/zheng/Desktop/Data Science/Presentations/Mod 9.2/UK Articles/UK Articles 2.txt'

with open(input_file7, 'r') as f:
    UKA2 = f.read()
    
print(UKA2[:500])
# Out:
# The number of daily UK cases of coronavirus has risen to 1,522 in 24 hours - up from 1,048 on Wednesday - the highest tally since mid-June. This is still much lower than the 5,000 new cases a day in April, at the peak of the epidemic. Cases have been rising across Europe and began edging up again in the UK in July, after falling in June. A number of areas have seen a spike in infections, with Birmingham and Northampton the latest places affected. And experts suspect a relatively small number of

# %% [markdown]
# Article 3: 30 Aug 2020: https://www.bbc.com/news/education-53947488
#
# #### Coronavirus: University return 'could spark Covid avalanche'

# %%
input_file8 = 'C:/Users/zheng/Desktop/Data Science/Presentations/Mod 9.2/UK Articles/UK Articles 3.txt'

with open(input_file8, 'r') as f:
    UKA3 = f.read()
    
print(UKA3[:500])
# Out:
# Universities in the UK are being urged to scrap plans for face-to-face teaching until Christmas in order to prevent a second wave of coronavirus. Academics' union UCU said more than a million students moving around the country was "a recipe for disaster". But university bosses say they have worked hard to plan for a safe return to all aspects of student life. It comes as daily recorded cases of coronavirus in the UK reached 1,715 in 24 hours, the highest since early June. Case numbers began edgi

# %% [markdown]
# Article 4: 2 Sep 2020: https://www.bbc.com/news/in-pictures-53996461
#
# #### Coronavirus: How it feels to be going back to school

# %%
input_file9 = 'C:/Users/zheng/Desktop/Data Science/Presentations/Mod 9.2/UK Articles/UK Articles 4.txt'

with open(input_file9, 'r') as f:
    UKA4 = f.read()
    
print(UKA4[:500])
# Out:
# 'I didn't want to send them back' "It's scary but we don't have a choice really," says Iram Kanwal. "You have to pay your fine or bring them to school. I would've been happy not sending them back right now because it's too soon, but [I'm] hoping for the best I guess." Iram says she worries about a second coronavirus peak, but admits having her children, aged 3 and 5, at home for so long was a bit of a "juggling act". Now her kids are returning to school and nursery, she says she's been telling t

# %% [markdown]
# Article 5: 5 Sep 2020: https://www.bbc.com/news/uk-politics-54035770
# #### Coronavirus: Civil servants 'must get back to offices quickly'

# %%
input_file10 = 'C:/Users/zheng/Desktop/Data Science/Presentations/Mod 9.2/UK Articles/UK Articles 5.txt'

with open(input_file10, 'r') as f:
    UKA5 = f.read()
    
print(UKA5[:500])
# Out:
# The government has urged Whitehall bosses to "move quickly" to get more staff back into the office.In a letter seen by the BBC, it says it is "strongly encouraging" attendance through rota systems, arguing this would be "hugely beneficial".The government says it wants 80% of civil servants to be able to attend their usual workplace at least once a week by the end of the month.But unions have described the government's attitude as outdated.They say most civil servants should expect to keep workin

# %% [markdown]
# ### 1.1.3 US Articles

# %% [markdown]
# Article 1: 24 Aug 2020: https://edition.cnn.com/2020/08/24/health/panic-attack-internet-search-coronavirus-trnd-wellness/index.html
#
# #### Acute anxiety: Internet searches for key words spiked to all-time high early in pandemic

# %%
input_file11 = 'C:/Users/zheng/Desktop/Data Science/Presentations/Mod 9.2/US Articles/US Articles 1.txt'

with open(input_file11, 'r') as f:
    USA1 = f.read()
    
print(USA1[:500])
# Out:
# As the coronavirus pandemic gained traction in the United States, internet searches for key words related to panic attacks and acute anxiety spiked.Google searches for anxiety symptoms from mid-March to mid-May were the highest they've been in the history of the search engine, according to researchers at the Qualcomm Institute's Center for Data Driven Health at the University of California San Diego.The study was published Monday in the Journal of the American Medical Association.In particular,

# %% [markdown]
# Article 2: 27 Aug 2020 https://edition.cnn.com/2020/08/27/world/global-coronavirus-attitudes-pew-intl/index.html
#
# #### US and UK are bottom of the pile in rankings of governments' handling of coronavirus pandemic

# %%
input_file12 = 'C:/Users/zheng/Desktop/Data Science/Presentations/Mod 9.2/US Articles/US Articles 2.txt'

with open(input_file12, 'r') as f:
    USA2 = f.read()
    
print(USA2[:500])
# Out:
# Americans rank dead last -- by a long way -- among citizens of more than a dozen countries who were asked whether their nation is more united now than it was before the coronavirus pandemic, according to a survey released Thursday. And they come in a statistical joint last place with the British on whether their country has handled the pandemic well, the poll finds. In the United States, fewer than two in 10 people (18%) said the country is more united now. That's a full 21 percentage points bel

# %% [markdown]
# Article 3: 29 Aug https://edition.cnn.com/2020/08/29/us/university-of-alabama-covid-19-cases-trnd/index.html
#
# #### Over 1,000 students have tested positive for Covid-19 at University of Alabama since classes resumed

# %%
input_file13 = 'C:/Users/zheng/Desktop/Data Science/Presentations/Mod 9.2/US Articles/US Articles 3.txt'

with open(input_file13, 'r') as f:
    USA3 = f.read()
    
print(USA3[:500])
# Out:
# More than 1,000 students at the University of Alabama have tested positive for Covid-19 since classes resumed on the Tuscaloosa campus less than two weeks ago, according to the University of Alabama System.The UA System coronavirus dashboard notes another 158 cases were recorded on campus over the course of the year prior to August 18, bringing the total to 1,201 cases. Classes resumed August 19.UA in Tuscaloosa has by far the most students who have tested positive for Covid-19 among the three c

# %% [markdown]
# Article 4: 1 Sep 2020 https://edition.cnn.com/2020/09/01/sport/jeffrey-lurie-philadelphia-eagles-nfl-covid-19-racism-spt-intl/index.html
#
# #### US government response to racism and Covid-19 is 'tragic embarrassment,' says NFL team owner

# %%
input_file14 = 'C:/Users/zheng/Desktop/Data Science/Presentations/Mod 9.2/US Articles/US Articles 4.txt'

with open(input_file14, 'r') as f:
    USA4 = f.read()
    
print(USA4[:500])
# Out:
# Philadelphia Eagles owner Jeffrey Lurie has criticized the US government's handling of the issues of systemic racism in the country and the coronavirus pandemic, labeling them a "tragic embarrassment."Protests have broken out across the country over the past few months, particularly after the police killing of George Floyd and the shooting of Jacob Blake. Meanwhile on Monday, the US topped six million cases of Covid-19, which has killed over 183,000 people. Lurie, who called the racism that stil

# %% [markdown]
# Article 5: 4 Sep 2020 https://edition.cnn.com/2020/09/04/health/us-coronavirus-friday/index.html
#
# #### The US coronavirus death toll is projected to reach 410,000 in the next 4 months if mask use wanes

# %%
input_file15 = 'C:/Users/zheng/Desktop/Data Science/Presentations/Mod 9.2/US Articles/US Articles 5.txt'

with open(input_file15, 'r') as f:
    USA5 = f.read()
    
print(USA5[:500])
# Out:
# More than 410,000 people in the US could die from the coronavirus by January 1, more than doubling the current death toll, a new model often cited by top health officials predicted Friday. That would mean 224,000 more lives lost in the US over the next four months. Near-universal mask use could cut the number of projected additional fatalities by more than half, according to the model from the University of Washington's Institute for Health Metrics and Evaluation. But it also warns the cumulativ

# %% [markdown]
# ### 1.2 Merge them all

# %%
# Creating a list of filenames 
filenames = [input_file1, input_file2, input_file3, input_file4, input_file5, input_file6, input_file7, input_file8, input_file9, input_file10, input_file11, input_file12, input_file13, input_file14, input_file15] 

company = ["CNA Article 1", "CNA Article 2", "CNA Article 3", "CNA Article 4", "CNA Article 5", "BBC Article 1", "BBC Article 2", "BBC Article 3", "BBC Article 4", "BBC Article 5", "CNN Article 1", "CNN Article 2", "CNN Article 3", "CNN Article 4", "CNN Article 5"]

# Open all 15 in write mode 
with open('merged.txt', 'w') as outfile: 
  
    # Iterate through list 
    for names in filenames: 
  
        # Open each file in read mode 
        with open(names) as infile: 
  
            # read the data from file1 and 
            # file2 and write it in file3 
            outfile.write(infile.read()) 
  
        # Add '\n' to enter data of file2 
        # from next line 
        outfile.write("\n")

# %%
with open('merged.txt', 'r') as f:
    merge = f.read()

# %% [markdown]
# ## 1.3 Convert to DataFrame

# %%
import csv

with open('merged.txt', 'r') as in_file:
    stripped = (line.strip() for line in in_file)
    lines = (line.split("\n+") for line in stripped if line)
    with open('merged_text.csv', 'w') as out_file:
        writer = csv.writer(out_file)
        writer.writerow(('text'))
        writer.writerows(lines)

# %%
df = pd.read_csv('merged_text.csv', encoding= 'unicode_escape')

df.head(15)
# Out:
#                                                     t   e   x  t.1
# 0   SINGAPORE: It was early January when PUBking o... NaN NaN  NaN
# 1   SINGAPORE: To ensure Singapore's strategic int... NaN NaN  NaN
# 2   SINGAPORE: Polytechnic graduate Andrew Lee was... NaN NaN  NaN
# 3   SINGAPORE: Even though community transmission ... NaN NaN  NaN
# 4   SINGAPORE: The circuit breaker, implemented fr... NaN NaN  NaN
# 5   Anxiety levels among young teenagers dropped d... NaN NaN  NaN
# 6   The number of daily UK cases of coronavirus ha... NaN NaN  NaN
# 7   Universities in the UK are being urged to scra... NaN NaN  NaN
# 8   'I didn't want to send them back' "It's scary ... NaN NaN  NaN
# 9   The government has urged Whitehall bosses to "... NaN NaN  NaN
# 10  As the coronavirus pandemic gained traction in... NaN NaN  NaN
# 11  Americans rank dead last -- by a long way -- a... NaN NaN  NaN
# 12  More than 1,000 students at the University of ... NaN NaN  NaN
# ...

# %%
df = df.drop(columns=['e','x', 't.1'])

df.head()
# Out:
#                                                    t
# 0  SINGAPORE: It was early January when PUBking o...
# 1  SINGAPORE: To ensure Singapore's strategic int...
# 2  SINGAPORE: Polytechnic graduate Andrew Lee was...
# 3  SINGAPORE: Even though community transmission ...
# 4  SINGAPORE: The circuit breaker, implemented fr...

# %%
df = df.rename(columns={'t':'Text'})

df.head()
# Out:
#                                                 Text
# 0  SINGAPORE: It was early January when PUBking o...
# 1  SINGAPORE: To ensure Singapore's strategic int...
# 2  SINGAPORE: Polytechnic graduate Andrew Lee was...
# 3  SINGAPORE: Even though community transmission ...
# 4  SINGAPORE: The circuit breaker, implemented fr...

# %%
df.shape
# Out:
# (15, 1)

# %%
df
# Out:
#                                                  Text
# 0   SINGAPORE: It was early January when PUBking o...
# 1   SINGAPORE: To ensure Singapore's strategic int...
# 2   SINGAPORE: Polytechnic graduate Andrew Lee was...
# 3   SINGAPORE: Even though community transmission ...
# 4   SINGAPORE: The circuit breaker, implemented fr...
# 5   Anxiety levels among young teenagers dropped d...
# 6   The number of daily UK cases of coronavirus ha...
# 7   Universities in the UK are being urged to scra...
# 8   'I didn't want to send them back' "It's scary ...
# 9   The government has urged Whitehall bosses to "...
# 10  As the coronavirus pandemic gained traction in...
# 11  Americans rank dead last -- by a long way -- a...
# 12  More than 1,000 students at the University of ...
# 13  Philadelphia Eagles owner Jeffrey Lurie has cr...
# 14  More than 410,000 people in the US could die f...

# %%
df['Articles'] = company

df
# Out:
#                                                  Text       Articles
# 0   SINGAPORE: It was early January when PUBking o...  CNA Article 1
# 1   SINGAPORE: To ensure Singapore's strategic int...  CNA Article 2
# 2   SINGAPORE: Polytechnic graduate Andrew Lee was...  CNA Article 3
# 3   SINGAPORE: Even though community transmission ...  CNA Article 4
# 4   SINGAPORE: The circuit breaker, implemented fr...  CNA Article 5
# 5   Anxiety levels among young teenagers dropped d...  BBC Article 1
# 6   The number of daily UK cases of coronavirus ha...  BBC Article 2
# 7   Universities in the UK are being urged to scra...  BBC Article 3
# 8   'I didn't want to send them back' "It's scary ...  BBC Article 4
# 9   The government has urged Whitehall bosses to "...  BBC Article 5
# 10  As the coronavirus pandemic gained traction in...  CNN Article 1
# 11  Americans rank dead last -- by a long way -- a...  CNN Article 2
# 12  More than 1,000 students at the University of ...  CNN Article 3
# ...

# %%
cols = list(df)
cols[1], cols[0] = cols[0], cols[1]
cols
# Out:
# ['Articles', 'Text']

# %%
df = df.loc[:,cols]

df
# Out:
#          Articles                                               Text
# 0   CNA Article 1  SINGAPORE: It was early January when PUBking o...
# 1   CNA Article 2  SINGAPORE: To ensure Singapore's strategic int...
# 2   CNA Article 3  SINGAPORE: Polytechnic graduate Andrew Lee was...
# 3   CNA Article 4  SINGAPORE: Even though community transmission ...
# 4   CNA Article 5  SINGAPORE: The circuit breaker, implemented fr...
# 5   BBC Article 1  Anxiety levels among young teenagers dropped d...
# 6   BBC Article 2  The number of daily UK cases of coronavirus ha...
# 7   BBC Article 3  Universities in the UK are being urged to scra...
# 8   BBC Article 4  'I didn't want to send them back' "It's scary ...
# 9   BBC Article 5  The government has urged Whitehall bosses to "...
# 10  CNN Article 1  As the coronavirus pandemic gained traction in...
# 11  CNN Article 2  Americans rank dead last -- by a long way -- a...
# 12  CNN Article 3  More than 1,000 students at the University of ...
# ...

# %%
df.index = df.index + 1

# %% [markdown]
# # 2. Clean Text

# %% [markdown]
# https://www.dataquest.io/blog/tutorial-text-classification-in-python-using-spacy/

# %% [markdown]
# We’ll create a spacy_tokenizer() function that accepts a sentence as input and processes the sentence into tokens, performing lemmatization, lowercasing, and removing stop words.

# %% [markdown]
# from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer
# from sklearn.base import TransformerMixin
# from sklearn.pipeline import Pipeline

# %%
import string
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
from spacy.lang.en import English

# Create our list of punctuation marks
punctuations = string.punctuation

# Create our list of stopwords
nlp = spacy.load("en_core_web_sm")
stop_words = spacy.lang.en.stop_words.STOP_WORDS

# Load English tokenizer, tagger, parser, NER and word vectors
parser = English()

# Creating our tokenizer function
def spacy_tokenizer(sentence):
    # Creating our token object, which is used to create documents with linguistic annotations.
    mytokens = parser(sentence)

    # Lemmatizing each token and converting each token into lowercase
    mytokens = [ word.lemma_.lower().strip() if word.lemma_ != "-PRON-" else word.lower_ for word in mytokens ]

    # Removing stop words
    mytokens = [ word for word in mytokens if word not in stop_words and word not in punctuations ]

    # return preprocessed list of tokens
    return mytokens

# %%
df['clean'] = df['Text'].apply(spacy_tokenizer)

# %%
df
# Out:
#          Articles                                               Text  \
# 1   CNA Article 1  SINGAPORE: It was early January when PUBking o...
# 2   CNA Article 2  SINGAPORE: To ensure Singapore's strategic int...
# 3   CNA Article 3  SINGAPORE: Polytechnic graduate Andrew Lee was...
# 4   CNA Article 4  SINGAPORE: Even though community transmission ...
# 5   CNA Article 5  SINGAPORE: The circuit breaker, implemented fr...
# 6   BBC Article 1  Anxiety levels among young teenagers dropped d...
# 7   BBC Article 2  The number of daily UK cases of coronavirus ha...
# 8   BBC Article 3  Universities in the UK are being urged to scra...
# 9   BBC Article 4  'I didn't want to send them back' "It's scary ...
# 10  BBC Article 5  The government has urged Whitehall bosses to "...
# 11  CNN Article 1  As the coronavirus pandemic gained traction in...
# 12  CNN Article 2  Americans rank dead last -- by a long way -- a...
# 13  CNN Article 3  More than 1,000 students at the University of ...
# ...

# %%
df['clean'] = df['clean'].apply(lambda x: " ".join([str(word) for word in x]))

# %%
df
# Out:
#          Articles                                               Text  \
# 1   CNA Article 1  SINGAPORE: It was early January when PUBking o...
# 2   CNA Article 2  SINGAPORE: To ensure Singapore's strategic int...
# 3   CNA Article 3  SINGAPORE: Polytechnic graduate Andrew Lee was...
# 4   CNA Article 4  SINGAPORE: Even though community transmission ...
# 5   CNA Article 5  SINGAPORE: The circuit breaker, implemented fr...
# 6   BBC Article 1  Anxiety levels among young teenagers dropped d...
# 7   BBC Article 2  The number of daily UK cases of coronavirus ha...
# 8   BBC Article 3  Universities in the UK are being urged to scra...
# 9   BBC Article 4  'I didn't want to send them back' "It's scary ...
# 10  BBC Article 5  The government has urged Whitehall bosses to "...
# 11  CNN Article 1  As the coronavirus pandemic gained traction in...
# 12  CNN Article 2  Americans rank dead last -- by a long way -- a...
# 13  CNN Article 3  More than 1,000 students at the University of ...
# ...

# %% [markdown]
# # 3 NER

# %%
#for visualization of Entity detection importing displacy from spacy:

from spacy import displacy

# %%
SGA1_NER = nlp(SGA1)

entities1 =[(i, i.label_, i.label) for i in SGA1_NER.ents]
entities1
# Out:
# [(early January, 'DATE', 391),
#  (first, 'ORDINAL', 396),
#  (just two months, 'DATE', 391),
#  (Nearly five months, 'DATE', 391),
#  (Outram, 'FAC', 9191306739292312949),
#  (the Jobs Support Scheme, 'ORG', 383),
#  (the past months, 'DATE', 391),
#  (one, 'CARDINAL', 397),
#  (Alvin Chua, 'PERSON', 380),
#  (June, 'DATE', 391),
#  (Singapore, 'GPE', 384),
#  (Mr Chua’s, 'ORG', 383),
#  (Heng Swee Keat, 'PERSON', 380),
#  (last week, 'DATE', 391),
#  (the Ministry of Trade and Industry, 'ORG', 383),
#  (The Singapore Nightlife Business Association, 'ORG', 383),
#  (about one-third, 'CARDINAL', 397),
#  (320, 'CARDINAL', 397),
#  (10.30pm, 'ORG', 383),
#  (Joseph Ong, 'PERSON', 380),
#  (Chua, 'PERSON', 380),
#  (the Urban Redevelopment Authority, 'ORG', 383),
#  (the Singapore Food Agency, 'ORG', 383),
#  (F&B, 'ORG', 383),
#  (Singapore, 'GPE', 384),
#  (10.30pm, 'ORG', 383),
#  (Mr Chua, 'PERSON', 380),
#  (F&B, 'ORG', 383),
#  (Cash Studio Family Karaoke, 'PERSON', 380),
# ...

# %%
displacy.render(SGA1_NER, style = "ent",jupyter = True)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">SINGAPORE: It was
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     early January
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  when PUBking opened its doors to welcome its
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
# ...

# %%
SGA2_NER = nlp(SGA2)

displacy.render(SGA2_NER, style = "ent",jupyter = True)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">SINGAPORE: To ensure
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Singapore
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# 's strategic interests are not compromised,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     the National Security Coordination Secretariat
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ...

# %%
SGA3_NER = nlp(SGA3)

displacy.render(SGA2_NER, style = "ent",jupyter = True)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">SINGAPORE: To ensure
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Singapore
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# 's strategic interests are not compromised,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     the National Security Coordination Secretariat
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ...

# %%
SGA4_NER = nlp(SGA4)

displacy.render(SGA4_NER, style = "ent",jupyter = True)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">SINGAPORE: Even though community transmission of COVID-19 has been low in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     recent weeks
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Singapore
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  will have to be prepared for a
# ...

# %%
SGA5_NER = nlp(SGA5)

displacy.render(SGA5_NER, style = "ent",jupyter = True)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">SINGAPORE: The circuit breaker, implemented from
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     April to June
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Singapore
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ...

# %%
UKA1_NER = nlp(UKA1)

displacy.render(UKA1_NER, style = "ent",jupyter = True)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">Anxiety levels among young teenagers dropped during the coronavirus pandemic, a study has suggested. Thirteen to 14-year-olds were less anxious during lockdown than they had been
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     last October
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , according to
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     the University of Bristol
# ...

# %%
UKA2_NER = nlp(UKA2)

displacy.render(UKA2_NER, style = "ent",jupyter = True)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">The number of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     daily
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     UK
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  cases of coronavirus has risen to
# ...

# %%
UKA3_NER = nlp(UKA3)

displacy.render(UKA3_NER, style = "ent",jupyter = True)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">Universities in the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     UK
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  are being urged to scrap plans for face-to-face teaching until
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Christmas
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  in order to prevent a
# ...

# %%
UKA4_NER = nlp(UKA4)

displacy.render(UKA4_NER, style = "ent",jupyter = True)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">'I didn't want to send them back' &quot;It's scary but we don't have a choice really,&quot; says
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Iram Kanwal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# . &quot;You have to pay your fine or bring them to school. I would've been happy not sending them back right now because it's too soon, but [I'm] hoping for the best I guess.&quot;
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Iram
# ...

# %%
UKA5_NER = nlp(UKA5)

displacy.render(UKA5_NER, style = "ent",jupyter = True)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">The government has urged
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Whitehall
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  bosses to &quot;move quickly&quot; to get more staff back into the office.In a letter seen by the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     BBC
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ...

# %%
USA1_NER = nlp(USA1)

displacy.render(USA1_NER, style = "ent",jupyter = True)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">As the coronavirus pandemic gained traction in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     the United States
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , internet searches for key words related to panic attacks and acute anxiety spiked.Google searches for anxiety symptoms from
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     mid-March
# ...

# %%
USA1_NER = nlp(USA1)

displacy.render(USA1_NER, style = "ent",jupyter = True)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">As the coronavirus pandemic gained traction in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     the United States
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , internet searches for key words related to panic attacks and acute anxiety spiked.Google searches for anxiety symptoms from
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     mid-March
# ...

# %%
USA2_NER = nlp(USA2)

displacy.render(USA2_NER, style = "ent",jupyter = True)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Americans
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  rank dead last -- by a long way -- among citizens of
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     more than a dozen
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# ...

# %%
USA3_NER = nlp(USA3)

displacy.render(USA3_NER, style = "ent",jupyter = True)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     More than 1,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  students at
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     the University of Alabama
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  have tested positive for Covid-19 since classes resumed on the
# ...

# %%
USA4_NER = nlp(USA4)

displacy.render(USA4_NER, style = "ent",jupyter = True)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Philadelphia Eagles
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  owner
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Jeffrey Lurie
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  has criticized the
# ...

# %%
USA5_NER = nlp(USA5)

displacy.render(USA5_NER, style = "ent",jupyter = True)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     More than 410,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  people in the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     US
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  could die from the coronavirus by
# ...

# %% [markdown]
# # 4. Sentimental Analysis

# %% [markdown]
# ## 4A VADER
#
# https://medium.com/analytics-vidhya/simplifying-social-media-sentiment-analysis-using-vader-in-python-f9e6ec6fc52f
# https://medium.com/swlh/simple-sentiment-analysis-for-nlp-beginners-and-everyone-else-using-vader-and-textblob-728da3dbe33d

# %%
#!pip install vaderSentiment

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
#Add VADER metrics to dataframe
df['compound_text'] = [analyzer.polarity_scores(v)['compound'] for v in df['Text']]
df['neg_text'] = [analyzer.polarity_scores(v)['neg'] for v in df['Text']]
df['neu_text'] = [analyzer.polarity_scores(v)['neu'] for v in df['Text']]
df['pos_text'] = [analyzer.polarity_scores(v)['pos'] for v in df['Text']]

# %%
#Add VADER metrics to dataframe
df['compound_clean'] = [analyzer.polarity_scores(v)['compound'] for v in df['clean']]
df['neg_clean'] = [analyzer.polarity_scores(v)['neg'] for v in df['clean']]
df['neu_clean'] = [analyzer.polarity_scores(v)['neu'] for v in df['clean']]
df['pos_clean'] = [analyzer.polarity_scores(v)['pos'] for v in df['clean']]

# %% [markdown]
# ## 4. B Text Blob

# %%
from textblob import TextBlob

# %%
#load the descriptions into textblob
desc_blob = [TextBlob(desc) for desc in df['Text']]
#add the sentiment metrics to the dataframe
df['tb_Pol_text'] = [b.sentiment.polarity for b in desc_blob]
df['tb_Subj_text'] = [b.sentiment.subjectivity for b in desc_blob]

# %%
#load the descriptions into textblob
desc_blob = [TextBlob(desc) for desc in df['clean']]
#add the sentiment metrics to the dataframe
df['tb_Pol_clean'] = [b.sentiment.polarity for b in desc_blob]
df['tb_Subj_clean'] = [b.sentiment.subjectivity for b in desc_blob]

# %%
SG = df[0:5]
SG
# Out:
#         Articles                                               Text  \
# 1  CNA Article 1  SINGAPORE: It was early January when PUBking o...
# 2  CNA Article 2  SINGAPORE: To ensure Singapore's strategic int...
# 3  CNA Article 3  SINGAPORE: Polytechnic graduate Andrew Lee was...
# 4  CNA Article 4  SINGAPORE: Even though community transmission ...
# 5  CNA Article 5  SINGAPORE: The circuit breaker, implemented fr...
#
#                                                clean  compound_text  neg_text  \
# 1  singapore early january pubking opened doors w...         0.9984     0.049
# 2  singapore ensure singapore strategic interests...         0.9614     0.077
# 3  singapore polytechnic graduate andrew lee init...         0.9998     0.032
# 4  singapore community transmission covid-19 low ...         0.9979     0.020
# 5  singapore circuit breaker implemented april ju...         0.9965     0.040
#
#    neu_text  pos_text  compound_clean  neg_clean  neu_clean  pos_clean  \
# ...

# %%
UK = df[5:10]
UK
# Out:
#          Articles                                               Text  \
# 6   BBC Article 1  Anxiety levels among young teenagers dropped d...
# 7   BBC Article 2  The number of daily UK cases of coronavirus ha...
# 8   BBC Article 3  Universities in the UK are being urged to scra...
# 9   BBC Article 4  'I didn't want to send them back' "It's scary ...
# 10  BBC Article 5  The government has urged Whitehall bosses to "...
#
#                                                 clean  compound_text  \
# 6   anxiety levels young teenagers dropped coronav...         0.2187
# 7   number daily uk cases coronavirus risen 1,522 ...         0.8575
# 8   universities uk urged scrap plans face face te...         0.9944
# 9   want send scary choice says iram kanwal pay fi...         0.9992
# 10  government urged whitehall bosses quickly staf...         0.8491
#
#     neg_text  neu_text  pos_text  compound_clean  neg_clean  neu_clean  \
# ...

# %%
US = df[10:]
US
# Out:
#          Articles                                               Text  \
# 11  CNN Article 1  As the coronavirus pandemic gained traction in...
# 12  CNN Article 2  Americans rank dead last -- by a long way -- a...
# 13  CNN Article 3  More than 1,000 students at the University of ...
# 14  CNN Article 4  Philadelphia Eagles owner Jeffrey Lurie has cr...
# 15  CNN Article 5  More than 410,000 people in the US could die f...
#
#                                                 clean  compound_text  \
# 11  coronavirus pandemic gained traction united st...        -0.9976
# 12  americans rank dead -- long way -- citizens do...         0.9976
# 13  1,000 students university alabama tested posit...         0.9421
# 14  philadelphia eagles owner jeffrey lurie critic...         0.7333
# 15  410,000 people die coronavirus january 1 doubl...        -0.9861
#
#     neg_text  neu_text  pos_text  compound_clean  neg_clean  neu_clean  \
# ...

# %%
TL1 = df.loc[ (df['Articles'] == 'CNA Article 1') | (df['Articles'] == 'BBC Article 1') | (df['Articles'] == 'CNN Article 1') ]
TL1
# Out:
#          Articles                                               Text  \
# 1   CNA Article 1  SINGAPORE: It was early January when PUBking o...
# 6   BBC Article 1  Anxiety levels among young teenagers dropped d...
# 11  CNN Article 1  As the coronavirus pandemic gained traction in...
#
#                                                 clean  compound_text  \
# 1   singapore early january pubking opened doors w...         0.9984
# 6   anxiety levels young teenagers dropped coronav...         0.2187
# 11  coronavirus pandemic gained traction united st...        -0.9976
#
#     neg_text  neu_text  pos_text  compound_clean  neg_clean  neu_clean  \
# 1      0.049     0.841     0.111          0.9973      0.067      0.759
# 6      0.079     0.845     0.076          0.0772      0.133      0.738
# 11     0.159     0.746     0.096         -0.9982      0.256      0.598
#
#     pos_clean  tb_Pol_text  tb_Subj_text  tb_Pol_clean  tb_Subj_clean
# ...

# %%
TL2 = df.loc[ (df['Articles'] == 'CNA Article 2') | (df['Articles'] == 'BBC Article 2') | (df['Articles'] == 'CNN Article 2') ]
TL2
# Out:
#          Articles                                               Text  \
# 2   CNA Article 2  SINGAPORE: To ensure Singapore's strategic int...
# 7   BBC Article 2  The number of daily UK cases of coronavirus ha...
# 12  CNN Article 2  Americans rank dead last -- by a long way -- a...
#
#                                                 clean  compound_text  \
# 2   singapore ensure singapore strategic interests...         0.9614
# 7   number daily uk cases coronavirus risen 1,522 ...         0.8575
# 12  americans rank dead -- long way -- citizens do...         0.9976
#
#     neg_text  neu_text  pos_text  compound_clean  neg_clean  neu_clean  \
# 2      0.077     0.795     0.127          0.9670      0.116      0.682
# 7      0.045     0.885     0.070          0.7717      0.108      0.744
# 12     0.039     0.841     0.120          0.9913      0.064      0.779
#
#     pos_clean  tb_Pol_text  tb_Subj_text  tb_Pol_clean  tb_Subj_clean
# ...

# %%
TL3 = df.loc[ (df['Articles'] == 'CNA Article 3') | (df['Articles'] == 'BBC Article 3') | (df['Articles'] == 'CNN Article 3') ]
TL3
# Out:
#          Articles                                               Text  \
# 3   CNA Article 3  SINGAPORE: Polytechnic graduate Andrew Lee was...
# 8   BBC Article 3  Universities in the UK are being urged to scra...
# 13  CNN Article 3  More than 1,000 students at the University of ...
#
#                                                 clean  compound_text  \
# 3   singapore polytechnic graduate andrew lee init...         0.9998
# 8   universities uk urged scrap plans face face te...         0.9944
# 13  1,000 students university alabama tested posit...         0.9421
#
#     neg_text  neu_text  pos_text  compound_clean  neg_clean  neu_clean  \
# 3      0.032     0.870     0.098          0.9996      0.047      0.803
# 8      0.053     0.850     0.096          0.9777      0.085      0.782
# 13     0.026     0.889     0.085          0.9821      0.037      0.784
#
#     pos_clean  tb_Pol_text  tb_Subj_text  tb_Pol_clean  tb_Subj_clean
# ...

# %%
TL4 = df.loc[ (df['Articles'] == 'CNA Article 4') | (df['Articles'] == 'BBC Article 4') | (df['Articles'] == 'CNN Article 4') ]
TL4
# Out:
#          Articles                                               Text  \
# 4   CNA Article 4  SINGAPORE: Even though community transmission ...
# 9   BBC Article 4  'I didn't want to send them back' "It's scary ...
# 14  CNN Article 4  Philadelphia Eagles owner Jeffrey Lurie has cr...
#
#                                                 clean  compound_text  \
# 4   singapore community transmission covid-19 low ...         0.9979
# 9   want send scary choice says iram kanwal pay fi...         0.9992
# 14  philadelphia eagles owner jeffrey lurie critic...         0.7333
#
#     neg_text  neu_text  pos_text  compound_clean  neg_clean  neu_clean  \
# 4      0.020     0.879     0.101          0.9959      0.030      0.815
# 9      0.045     0.786     0.170          0.9938      0.081      0.699
# 14     0.087     0.818     0.096         -0.5998      0.158      0.688
#
#     pos_clean  tb_Pol_text  tb_Subj_text  tb_Pol_clean  tb_Subj_clean
# ...

# %%
TL5 = df.loc[ (df['Articles'] == 'CNA Article 5') | (df['Articles'] == 'BBC Article 5') | (df['Articles'] == 'CNN Article 5') ]
TL5
# Out:
#          Articles                                               Text  \
# 5   CNA Article 5  SINGAPORE: The circuit breaker, implemented fr...
# 10  BBC Article 5  The government has urged Whitehall bosses to "...
# 15  CNN Article 5  More than 410,000 people in the US could die f...
#
#                                                 clean  compound_text  \
# 5   singapore circuit breaker implemented april ju...         0.9965
# 10  government urged whitehall bosses quickly staf...         0.8491
# 15  410,000 people die coronavirus january 1 doubl...        -0.9861
#
#     neg_text  neu_text  pos_text  compound_clean  neg_clean  neu_clean  \
# 5      0.040     0.867     0.093          0.9950      0.054      0.806
# 10     0.053     0.882     0.065          0.9884      0.084      0.764
# 15     0.084     0.845     0.071         -0.9456      0.114      0.777
#
#     pos_clean  tb_Pol_text  tb_Subj_text  tb_Pol_clean  tb_Subj_clean
# ...

# %% [markdown]
# # 5 Visualiation of Results

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # 5A Compare within each country

# %% [markdown]
# ### 5.A.1 Overall Sentiment

# %% [markdown]
# #### 5.A.1.1 Compound Text

# %%
sns.barplot(x='Articles', y='compound_text', data = SG)
# Out:
# <AxesSubplot:xlabel='Articles', ylabel='compound_text'>

# %%
sns.barplot(x='Articles', y='compound_text', data = UK)
# Out:
# <AxesSubplot:xlabel='Articles', ylabel='compound_text'>

# %%
sns.barplot(x='Articles', y='compound_text', data = US)
# Out:
# <AxesSubplot:xlabel='Articles', ylabel='compound_text'>

# %% [markdown]
# #### 5.A.1.2 Polarity Score

# %%
sns.barplot(x='Articles', y='tb_Pol_text', data = SG)
# Out:
# <AxesSubplot:xlabel='Articles', ylabel='tb_Pol_text'>

# %%
sns.barplot(x='Articles', y='tb_Pol_text', data = UK)
# Out:
# <AxesSubplot:xlabel='Articles', ylabel='tb_Pol_text'>

# %%
sns.barplot(x='Articles', y='tb_Pol_text', data = US)
# Out:
# <AxesSubplot:xlabel='Articles', ylabel='tb_Pol_text'>

# %% [markdown]
# #### 5.A.1.3 Subjectivity Text

# %%
sns.barplot(x='Articles', y='tb_Subj_text', data = SG)
# Out:
# <AxesSubplot:xlabel='Articles', ylabel='tb_Subj_text'>

# %%
sns.barplot(x='Articles', y='tb_Subj_text', data = UK)
# Out:
# <AxesSubplot:xlabel='Articles', ylabel='tb_Subj_text'>

# %%
sns.barplot(x='Articles', y='tb_Subj_text', data = US)
# Out:
# <AxesSubplot:xlabel='Articles', ylabel='tb_Subj_text'>

# %% [markdown]
# ### 5.A.2 The Breakdown

# %% [markdown]
# #### 5.A.2.1 Positive Text

# %%
sns.barplot(x='Articles', y='pos_text', data = SG)
# Out:
# <AxesSubplot:xlabel='Articles', ylabel='pos_text'>

# %%
sns.barplot(x='Articles', y='pos_text', data = UK)
# Out:
# <AxesSubplot:xlabel='Articles', ylabel='pos_text'>

# %%
sns.barplot(x='Articles', y='pos_text', data = US)
# Out:
# <AxesSubplot:xlabel='Articles', ylabel='pos_text'>

# %% [markdown]
# #### 5.A.2.2 Neutral Text

# %%
sns.barplot(x='Articles', y='neu_text', data = SG)
# Out:
# <AxesSubplot:xlabel='Articles', ylabel='neu_text'>

# %%
sns.barplot(x='Articles', y='neu_text', data = UK)
# Out:
# <AxesSubplot:xlabel='Articles', ylabel='neu_text'>

# %%
sns.barplot(x='Articles', y='neu_text', data = US)
# Out:
# <AxesSubplot:xlabel='Articles', ylabel='neu_text'>

# %% [markdown]
# #### 5.A.2.3 Negative Text

# %%
sns.barplot(x='Articles', y='neg_text', data = SG)
# Out:
# <AxesSubplot:xlabel='Articles', ylabel='neg_text'>

# %%
sns.barplot(x='Articles', y='neg_text', data = UK)
# Out:
# <AxesSubplot:xlabel='Articles', ylabel='neg_text'>

# %%
sns.barplot(x='Articles', y='neg_text', data = US)
# Out:
# <AxesSubplot:xlabel='Articles', ylabel='neg_text'>

# %% [markdown]
# # 5.B Compare the 3 countries over the same(estimated) period of date

# %% [markdown]
# ### 5.B.1 Overall Sentiment

# %% [markdown]
# #### 5.B.1.1 Compound Text

# %%
sns.barplot(x='Articles', y='compound_text', data = TL1)
# Out:
# <AxesSubplot:xlabel='Articles', ylabel='compound_text'>

# %%
sns.barplot(x='Articles', y='compound_text', data = TL2)
# Out:
# <AxesSubplot:xlabel='Articles', ylabel='compound_text'>

# %%
sns.barplot(x='Articles', y='compound_text', data = TL3)
# Out:
# <AxesSubplot:xlabel='Articles', ylabel='compound_text'>

# %%
sns.barplot(x='Articles', y='compound_text', data = TL4)
# Out:
# <AxesSubplot:xlabel='Articles', ylabel='compound_text'>

# %%
sns.barplot(x='Articles', y='compound_text', data = TL5)
# Out:
# <AxesSubplot:xlabel='Articles', ylabel='compound_text'>

# %% [markdown]
# #### 5.B.1.2 Polarity Score

# %%
sns.barplot(x='Articles', y='tb_Pol_text', data = TL1)
# Out:
# <AxesSubplot:xlabel='Articles', ylabel='tb_Pol_text'>

# %%
sns.barplot(x='Articles', y='tb_Pol_text', data = TL2)
# Out:
# <AxesSubplot:xlabel='Articles', ylabel='tb_Pol_text'>

# %%
sns.barplot(x='Articles', y='tb_Pol_text', data = TL3)
# Out:
# <AxesSubplot:xlabel='Articles', ylabel='tb_Pol_text'>

# %%
sns.barplot(x='Articles', y='tb_Pol_text', data = TL4)
# Out:
# <AxesSubplot:xlabel='Articles', ylabel='tb_Pol_text'>

# %%
sns.barplot(x='Articles', y='tb_Pol_text', data = TL5)
# Out:
# <AxesSubplot:xlabel='Articles', ylabel='tb_Pol_text'>

# %% [markdown]
# #### 5.B.1.3 Subjectivity Text

# %%
sns.barplot(x='Articles', y='tb_Subj_text', data = TL1)
# Out:
# <AxesSubplot:xlabel='Articles', ylabel='tb_Subj_text'>

# %%
sns.barplot(x='Articles', y='tb_Subj_text', data = TL2)
# Out:
# <AxesSubplot:xlabel='Articles', ylabel='tb_Subj_text'>

# %%
sns.barplot(x='Articles', y='tb_Subj_text', data = TL3)
# Out:
# <AxesSubplot:xlabel='Articles', ylabel='tb_Subj_text'>

# %%
sns.barplot(x='Articles', y='tb_Subj_text', data = TL4)
# Out:
# <AxesSubplot:xlabel='Articles', ylabel='tb_Subj_text'>

# %%
sns.barplot(x='Articles', y='tb_Subj_text', data = TL5)
# Out:
# <AxesSubplot:xlabel='Articles', ylabel='tb_Subj_text'>

# %% [markdown]
# ### 5.B.2 The Breakdown

# %% [markdown]
# #### 5.B.2.1 Positive Text

# %%
sns.barplot(x='Articles', y='pos_text', data = TL1)
# Out:
# <AxesSubplot:xlabel='Articles', ylabel='pos_text'>

# %%
sns.barplot(x='Articles', y='pos_text', data = TL2)
# Out:
# <AxesSubplot:xlabel='Articles', ylabel='pos_text'>

# %%
sns.barplot(x='Articles', y='pos_text', data = TL3)
# Out:
# <AxesSubplot:xlabel='Articles', ylabel='pos_text'>

# %%
sns.barplot(x='Articles', y='pos_text', data = TL4)
# Out:
# <AxesSubplot:xlabel='Articles', ylabel='pos_text'>

# %%
sns.barplot(x='Articles', y='pos_text', data = TL5)
# Out:
# <AxesSubplot:xlabel='Articles', ylabel='pos_text'>

# %% [markdown]
# #### 5.B.2.2 Neutral Text

# %%
sns.barplot(x='Articles', y='neu_text', data = TL1)
# Out:
# <AxesSubplot:xlabel='Articles', ylabel='neu_text'>

# %%
sns.barplot(x='Articles', y='neu_text', data = TL2)
# Out:
# <AxesSubplot:xlabel='Articles', ylabel='neu_text'>

# %%
sns.barplot(x='Articles', y='neu_text', data = TL3)
# Out:
# <AxesSubplot:xlabel='Articles', ylabel='neu_text'>

# %%
sns.barplot(x='Articles', y='neu_text', data = TL4)
# Out:
# <AxesSubplot:xlabel='Articles', ylabel='neu_text'>

# %%
sns.barplot(x='Articles', y='neu_text', data = TL5)
# Out:
# <AxesSubplot:xlabel='Articles', ylabel='neu_text'>

# %% [markdown]
# #### 5.B.2.3 Negative Text

# %%
sns.barplot(x='Articles', y='neg_text', data = TL1)
# Out:
# <AxesSubplot:xlabel='Articles', ylabel='neg_text'>

# %%
sns.barplot(x='Articles', y='neg_text', data = TL2)
# Out:
# <AxesSubplot:xlabel='Articles', ylabel='neg_text'>

# %%
sns.barplot(x='Articles', y='neg_text', data = TL3)
# Out:
# <AxesSubplot:xlabel='Articles', ylabel='neg_text'>

# %%
sns.barplot(x='Articles', y='neg_text', data = TL4)
# Out:
# <AxesSubplot:xlabel='Articles', ylabel='neg_text'>

# %%
sns.barplot(x='Articles', y='neg_text', data = TL5)
# Out:
# <AxesSubplot:xlabel='Articles', ylabel='neg_text'>
